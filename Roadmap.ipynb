# %% [markdown]
# # <u> **1. Basics in python** </u>
# ### <u> Standard libraries </u>
# ```python
# import math
# ```
# - **Working with real numbers**: Do basic mathematics here, like *sin*, *log* or *sqrt*. For complex numbers use `cmath`
#
# ```python
# import random
# ```
# - **Working with random variables**: For discrete and continuous random variables. **Not** actual random variables, only pseudo random. Set seeds for important scientific projects.
#
# ```python
# import time
# ```
# - **Tracking time in python for optimization**: Different ways to track runtime. For simple time tracking `time.time()`, for more precision `time.perf_counter()` or `time.process_time()`
# - **Working with actual time**
# - **Also see**: `datetime` more modern and object oriented, `calendar` to work with calendars, `sched` for scheduling
# ```python
# import re
# ```
# - **Language to search, find and replace patterns in strings**: pattern matching (e.g. E-Mail, phone number, words), validating inputs, text processing (e.g. replace, split) and much more
# ```python
# import os
# ```
# - **Operating system functions in python**: work with files, folders and processes independent of your operating system
# - **Also see**: `shutil` (shell utilities) the big brother of `os` for functions that go beyond *creating* and *deleting* files, like *copying* or *moving*
#
# ### <u> Modular programming </u>
# When working on a large project consider using modules (extra programs beside the main.py with functions, classes etc.). <br>
# To do so use
# ```python
# import custom_module as shortcut
# from custom_module import function_a, function_b
# ```
#
# For more see https://docs.python.org/3/library/index.html
#
# ---
# # <u> **2. NumPy** </u>
# ```python
# import numpy as np
# ```
# - **Working with Arrays**: In NumPy, the `ndarray`-object is the central element
# - **Mathematical and Statistical Operations**: NumPy can perform various calculations such as sums `sum`, mean `mean`,
# standard deviation `std`, sine `sin`, logarithm`log` etc.
# - **Linear Algebra**: Solving linear equation systems `linalg.solve`, inverse of a matrix `linalg.inv`,
# eigenvalue calculation `linalg.eig`, determinants `linalg.det`, various matrix operations → addition A + B, multiplication `dot`, element-wise multiplication A * B, transposition `.T`
# - **Nice to know**:
#     - NumPy is the foundation for many other libraries like Pandas, SciPy, TensorFlow, and Scikit-Learn
#     - NumPy is implemented in C → fast, efficient, and requires less memory
#
# For more see https://numpy.org/
#
# ---
# # <u> **3. Matplotlib** </u>
# ```python
# import matplotlib.pyplot as plt
# ```
# - **Creating charts and graphs**: `pyplot` makes creating plots in Matplotlib significantly easier and is the standard approach for visualizations in Python.
#
# For more see https://matplotlib.org/
#
# ---
# # <u> **4. Pydantic** </u>
# ```python
# from pydantic import Basemodel  # and more if required
# ```
# - **Type hints**: check and validate your data
# - **Serialization**: Pydantic provides functionality to serialize model in three ways:
#
#     1) To a Python `dict` made up of the associated Python objects.
#     2) To a Python `dict` made up only of “jsonable” types.
#     3) To a JSON string.
#
# A JSON Schema can be generated for any Pydantic schema — allowing self-documenting APIs and integration with a wide variety of tools which support the JSON Schema format. For more see https://pydantic.dev/docs/validation/latest/concepts/json_schema/
#
# ---
# # <u> **5. Pytest** </u>
# The `Pytest` framework makes it easy to write small, readable tests, and can scale to support complex functional testing for applications and libraries.
# - It's recommended to use separate directories for your code and for the tests.
# - The test files have to follow the form `test_*.py` or `*_test.py`.
# - All function tests have to start with test_
# - There is way more possible with pytest than just simple function tests (which is shown here).
#
# For more see https://docs.pytest.org/en/stable/index.html
#
# ---
#
# # <u> **6. Linopy** </u>
# ```python
# from linopy import Model
# import highspy
# ```
# - **Linear, Integer, Mixed-Integer, or Quadratic Programming**: Linopy is as a user-friendly interface to define variables and constraints.
# It serves as a bridge, connecting data analysis packages such like xarray & pandas with problem solvers.
# - You will need to install a solver (`HiGHS` is recommended -> free, open source and fast)
# - To install: uv add highspy *or* uv add "linopy[solvers]"
#
# For more see https://linopy.readthedocs.io/en/latest/
#
# ---
# # <u> **7. Pandas** </u>
# # <u> **8. Scipy** </u>
# # <u> **9. Scikit-Optimize** </u>
# # <u> **10. Seaborn** </u>
# # <u> **11. Polars** </u>
# # <u> **12. Statsmodel** </u>
# # <u> **13. Scikit-Learn** </u>
# # <u> **14. Tensorflow** </u>
# # <u> **15. SQL in Python und VSC** </u>
