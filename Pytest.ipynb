# %% [markdown]
# # **Pytest** in a nutshell (testing)

# %% [markdown]
# - Go to `test_pytest.py` and `pytest_real` for the actual test.
# - Below is just a copy that doesn't really work.
# - In fact it's uncommon to use pytest for jupyter notebook, because they are meant for small experiments or presentations.
# - Theoretically you can start your test_*.py in the directory that this .ipynb is in with !pytest.
# ---
# - It's recommended to use separate directories for your code and for the tests.
# - The test files have to follow the form `test_*.py` or `*_test.py`.
# - All function tests have to start with test_
# - There is way more possible with pytest than just simple function tests (which is shown here).
# See https://docs.pytest.org/en/stable/index.html for more information

# %%
# Content of pytest_real.py
# Pytest in a nutshell Part 1/2

def add(a,b):
    return a + b

def calculate_profit(price_buy, price_sell):
    return price_sell - price_buy

def calculated_profit_advanced(price_buy, price_sell, fee):
    return price_sell - price_buy - fee

# %%
# Content of test_pytest.py
# Pytest in a nutshell Part 2/2

from pytest_real import add, calculate_profit, calculated_profit_advanced

def test_add():
    assert add(2,3) == 5

def test_profit():
    assert calculate_profit(50,80) == 30

# This will show an error 
def test_profit_advanced_wrong():
    assert calculated_profit_advanced(50,80) == 29

def test_profit_advanced():
    assert calculated_profit_advanced(50,80,1) == 29

# !pytest
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.11.15, pytest-9.1.1, pluggy-1.6.0
# rootdir: c:\Users\Minh Tri\Desktop\python_guide
# configfile: pyproject.toml
# collected 4 items
#
# test_pytest.py ..F.                                                      [100%]
#
# ================================== FAILURES ===================================
# _________________________ test_profit_advanced_wrong __________________________
#
#     def test_profit_advanced_wrong():
# >       assert calculated_profit_advanced(50,80) == 29
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# E       TypeError: calculated_profit_advanced() missing 1 required positional argument: 'fee'
#
# test_pytest.py:13: TypeError
# =========================== short test summary info ===========================
# FAILED test_pytest.py::test_profit_advanced_wrong - TypeError: calculated_profit_advanced() missing 1 required positional argum...
# ...
